# %% [markdown]
# <a href="https://colab.research.google.com/github/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/%C3%81lgebra_lineal_con_Python_Vectores_y_operaciones_con_vectores_NBF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p><img alt="logo.fua" height="100px" src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/Logo%20UAm%C3%A9rica%20nuevo%202021.ai_page-0005.jpg?raw=true" align="left" hspace="0px" vspace="0px"></p>
#
# <p><img alt="logo.fua" height="26px" src="https://mirrors.creativecommons.org/presskit/buttons/88x31/svg/by-nd.svg" align="right" hspace="0px" vspace="11px"></p>
#
#
# <center> <font size="6"><b>ÁLGEBRA LINEAL CON PYTHON</b>&nbsp;&nbsp;&nbsp;&nbsp;<center><I>Jhonny Osorio Gallego</I> &nbsp; &nbsp;&nbsp; &nbsp;&nbsp; &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<p></font></center>

# %% [markdown]
# # **VECTORES Y OPERACIONES CON VECTORES**

# %% [markdown]
# ## **LIBRERÍA SIMBÓLICA SYMPY**
# **SymPy** es una biblioteca de Python para matemáticas simbólicas. Su objetivo es convertirse en un sistema de álgebra computacional (CAS) con todas las funciones, manteniendo el código lo más simple posible para que sea comprensible y fácilmente extensible. SymPy está escrito completamente en Python.[sympy.org](https://www.sympy.org/en/index.html)

# %%
from sympy import *
x,y,z,A,B,C,a = symbols("x y z A B C a ")

# %% [markdown]
# ## **MÓDULO EXTERNO PARA LA GRAFICACIÓN DE VECTORES**
#
# El siguiente módulo permite la representación gráfica de vectores en el plano y el espacio y hace uso de la librería  de graficación **Plotly** y de arreglos multidimensionales **NumPy**, se crea como herramienta para una mejor comprensión de los conceptos vectoriales desde las actividades con el lenguaje de programación Python y se nombra como **PlotLinearAlgebra**, el cual contiene el submodulo de graficación **plotvectors** la pagina oficial es : [https://pypi.org/project/PlotLinearAlgebra/](https://pypi.org/project/PlotLinearAlgebra/).

# %%
# %%capture
# !pip install PlotLinearAlgebra
from PlotLinearAlgebra.plotvectors import *

# %% [markdown]
# # **MAGNITUD FÍSICA**
#
# Son aquellas propiedades que poseen lo cuerpos f́ísicos y fenomenos que son susceptibles a ser medidas.
#
# **Ejemplos:**  *la longitud, la masa, el tiempo, la velocidad, la fuerza y la temperatura*.
#
# # **Magnitudes físicas escalares**
#
# Son aquellas que para su definición necesitan de un número real y una unidad de  medida.
#
# **Ejemplos:**  *la longitud, la masa, el tiempo y la temperatura*.
#
#
# # **Magnitudes físicas  vectoriales**
#
# Son aquellas que para su definición no solamente necesitan de un número real y una unidad de  medida, tambien se necesita especificar su dirección y sentido, para describirlas se usan los **vectores**.
#
# **Ejemplos:**  *el desplazamiento, la velocidad, la cantidad de movimiento y la fuerza*.

# %% [markdown]
# # **DEFINICIÓN GEOMÉTRICA DE VECTOR**
#
# Se define como un segmento de recta dirigido,  entre sus caracteristicas podemos apreciar: *punto inicial, magnitud, dirección y sentido*.
#
#
#
# *   **Magnitud :** se define como la longitud del vector.
# *   **Dirección:** es la recta soporte, recta directriz o linea de acción que contiene al vector.
# *   **Sentido:** es la la punta de la flecha.
#
# El ángulo $\theta$ que se mide respecto a una recta en particular determina  la dirreción y el sentido del vector.
#
#
#
#
#
#
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/vector%20geom%C3%A9trico%20final.png?raw=true"  height="300" />

# %% [markdown]
# # **VECTORES IGUALES O EQUIVALENTES**
#
# La relación que permite determinar si dos vectores son equivalentes se llama **relación de equipolencia**, dos vectores o mas son equipolentes si tienen la misma *magnitud, dirección y sentido*.
#
# Decimos que dos vectores tienen la misma dirección si sus rectas directrices son paralelas.
#
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/igualdad%20vectores.png?raw=true"  height="300" /> </center>
#
# ¿ Cuales de los siguientes vectores tienen la misma dirección, cuales tienen el mismo sentido, cuales tienen la misma magnitud y cuales son equipolentes?
#
#
#
#
# # **Equipolencia de vectores desde la  representación geométrica-cartesiana**
#
# Decimos que dos vectores en el plano $\overrightarrow{AB}$ y $\overrightarrow{CD}$ donde $A = (A_x,A_y)$, $B = (B_x,B_y)$, $C= (C_x,C_y)$ y  $D= (D_x,D_y)$ son iguales, si se cumple:
#
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/equipolencia-cartesiana.png?raw=true"  height="300" /> </center>

# %% [markdown]
# # **DEFINICIÓN ANALÍTICA DE VECTOR**
# Un vector con dimensión $n$, es una $n$-tupla de números reales que pertenece a $\mathbb {R} ^{n}$ en donde cada elemento de la  $n$-tupla recibe el nómbre de componente.
#
# Definimos $V_n$ como **el espacio vectorial** de $n$-tuplas, como el conjunto de todos los vectores con dimensión $n$.
#
# De esta manera un vector $\vec{V} \in V_n$ se nota cómo:
#
# $$\vec{V} = (x_1,x_2,\cdots,x_n) = x_1\hat{e_1} + x_2\hat{e_2} +\cdots+ x_n\hat{e_n}$$
#
# Donde  $\hat{e_i}$ son los respectivos vectores unitarios para cada una de las componentes y donde $\hat{e_1}= \hat{\imath} $,  $\hat{e_2}= \hat{\jmath}$, $\hat{e_3}= \hat{k} $
#
#
# Cuando los vectores pertenecen a $\mathbb {R} ^{n}$ con $n=1,2 \hspace{0.2cm} \text{o} \hspace{0.2cm} 3$  podemos realizar **representaciones geométricas** de los mismos respectivamente en la recta, el plano y el espacio.

# %% [markdown]
# #**DEFINICIÓN DE UN VECTOR EN PYTHON**
#
# En la libreria **SymPy** de python un vector se define como una matriz columna, o como combinación de vectores unitarios, existen otras librerías como NumPy en donde se define como un arreglo, puede consultar en la documentación oficial [https://numpy.org/](https://numpy.org/).

# %% [markdown]
# # **Definición como una matriz**
# Esta sintaxis para contruir el vector se realiza la función **Matrix** de la librería **SymPy**.

# %%
A = Matrix([1,2])
A
# Out:
# Matrix([
# [1],
# [2]])

# %%
A = Matrix([2,3,5])
A
# Out:
# Matrix([
# [2],
# [3],
# [5]])

# %%
A = Matrix([2,3,5,6])
A
# Out:
# Matrix([
# [2],
# [3],
# [5],
# [6]])

# %% [markdown]
# # **Definición como combinación lineal de vectores unitarios**
#
# Esta sintaxis para contruir el vector se realiza con la función **ReferenceFrame** de la librería **sympy.physics.vector**.

# %%
from sympy.physics.vector import *
e = ReferenceFrame('e')

i = e.x 
j = e.y 
k = e.z

A = 2*i + 3*j +5*k
A
# Out:
# 2*e.x + 3*e.y + 5*e.z

# %% [markdown]
# # **GRAFICACIÓN DE VECTORES CON EL MÓDULO PLOTVECTOR**
#
# #**Graficación de vectores bidimensionales**

# %% [markdown]
# ###**Con punto inicial en el origen**

# %%
A = Matrix([2,5])
plotvectors2D(A)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="20e52193-4f1e-4e3d-8523-558bf36d4798" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("20e52193-4f1e-4e3d-8523-558bf36d4798")) {                    Plotly.newPlot(                        "20e52193-4f1e-4e3d-8523-558bf36d4798",                        [{"marker":{"color":"rgb(3,252,10)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[0,2.0],"y":[0,5.0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(3,252,10)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":2.0,"xref":"x","y":5.0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-0.54,"axref":"x","ay":0,"ayref":"y","x":2.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-0.54,"ayref":"y","x":0,"xref":"x","y":5.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039 ...

# %% [markdown]
# ###**Con punto inicial y punto final dado**

# %%
A = (1,2)
B = (3,5)
V = Matrix([2,3])

plotvectors2D([A,B],V)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="4b5ae53d-919e-4ae2-aea7-bf752bf2fd59" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b5ae53d-919e-4ae2-aea7-bf752bf2fd59")) {                    Plotly.newPlot(                        "4b5ae53d-919e-4ae2-aea7-bf752bf2fd59",                        [{"marker":{"color":"rgb(217,167,101)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[1,3],"y":[2,5]},{"marker":{"color":"rgb(87,209,215)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[0,2.0],"y":[0,3.0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(217,167,101)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":1,"axref":"x","ay":2,"ayref":"y","showarrow":true,"x":3,"xref":"x","y":5,"yref":"y"},{"arrowcolor":"rgb(87,209,215)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":2.0,"xref":"x","y":3.0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-0.54,"axref":"x","ay":0,"ayref":"y","x":3.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-0.54,"ayref":"y","x":0,"xref":"x","y":5.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44 ...

# %% [markdown]
# ###**Equipolente a otro vector con punto inicial dado**

# %%
A = Matrix([2,3])
plotvectors2D(A,[(1,2),A])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="caa6919c-65eb-40de-9452-3391dd1e44e7" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("caa6919c-65eb-40de-9452-3391dd1e44e7")) {                    Plotly.newPlot(                        "caa6919c-65eb-40de-9452-3391dd1e44e7",                        [{"marker":{"color":"rgb(158,83,208)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[0,2.0],"y":[0,3.0]},{"marker":{"color":"rgb(50,57,248)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[1,3.0],"y":[2,5.0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(158,83,208)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":2.0,"xref":"x","y":3.0,"yref":"y"},{"arrowcolor":"rgb(50,57,248)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":1,"axref":"x","ay":2,"ayref":"y","showarrow":true,"x":3.0,"xref":"x","y":5.0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-0.54,"axref":"x","ay":0,"ayref":"y","x":3.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-0.54,"ayref":"y","x":0,"xref":"x","y":5.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[ ...

# %% [markdown]
# #**Graficación de vectores trididimensionales**
#
# ###**Con punto inicial en el origen**

# %%
A = [1,2,3]
plotvectors3D(A)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="94fcb5d8-e1ae-4ad0-81aa-0613a6a2ad3e" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("94fcb5d8-e1ae-4ad0-81aa-0613a6a2ad3e")) {                    Plotly.newPlot(                        "94fcb5d8-e1ae-4ad0-81aa-0613a6a2ad3e",                        [{"line":{"color":"rgb(135,63,206)","width":7},"marker":{"color":"rgb(135,63,206)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1],"y":[0,2],"z":[0,3]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(135,63,206)"],[1,"rgb(135,63,206)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.2,"type":"cone","u":[1],"v":[2],"w":[3],"x":[1],"y":[2],"z":[3]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.2,1.2],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.12,"type":"cone","u":[1.2],"v":[0],"w":[0],"x":[1.2],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-0.2,2.2],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.12,"type":"cone","u":[0],"v":[2.2],"w":[0],"x":[0],"y":[2.2],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.5,3.2]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.12,"type":"cone","u":[0],"v":[0],"w":[3.2],"x":[0],"y":[0],"z":[3.2]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953 ...

# %% [markdown]
# ###**Con punto inicial y punto final dado**

# %%
A = (1,2,3)
B = (5,4,6)

plotvectors3D([A,B])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="80d6cd8c-7f5e-4c8a-859f-e9957181b3da" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("80d6cd8c-7f5e-4c8a-859f-e9957181b3da")) {                    Plotly.newPlot(                        "80d6cd8c-7f5e-4c8a-859f-e9957181b3da",                        [{"hoverinfo":"name+text","hovertext":"Tail=(1,2,3)\nHead=(5,4,6)","line":{"color":"rgb(83,13,189)","width":7},"marker":{"color":"rgb(83,13,189)","size":1},"name":"vector 1","type":"scatter3d","x":[1,5],"y":[2,4],"z":[3,6]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(83,13,189)"],[1,"rgb(83,13,189)"]],"hoverinfo":"skip","name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.5,"type":"cone","u":[2.0],"v":[1.0],"w":[1.5],"x":[4.9748],"y":[3.9874],"z":[5.9811]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.5,5.5],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.3,"type":"cone","u":[5.5],"v":[0],"w":[0],"x":[5.5],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-0.5,4.5],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.3,"type":"cone","u":[0],"v":[4.5],"w":[0],"x":[0],"y":[4.5],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.8,6.5]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.3,"type":"cone","u":[0],"v":[0],"w":[6.5],"x":[0],"y":[0],"z":[6.5]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9 ...

# %% [markdown]
# ###**Equipolente a otro vector con punto inicial dado**

# %%
A = Matrix([1,2,3])
plotvectors3D(A,[(1,3,5),A])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="719e6445-1958-4473-a6c9-4e247a9380c3" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("719e6445-1958-4473-a6c9-4e247a9380c3")) {                    Plotly.newPlot(                        "719e6445-1958-4473-a6c9-4e247a9380c3",                        [{"line":{"color":"rgb(7,241,193)","width":7},"marker":{"color":"rgb(7,241,193)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1.0],"y":[0,2.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(7,241,193)"],[1,"rgb(7,241,193)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.5,"type":"cone","u":[1.0],"v":[2.0],"w":[3.0],"x":[1.0],"y":[2.0],"z":[3.0]},{"hoverinfo":"name+text","hovertext":"Tail=(1,3,5)\nHead=(2.0,5.0,8.0)","line":{"color":"rgb(134,137,55)","width":7},"marker":{"color":"rgb(134,137,55)","size":1},"name":"vector 2","type":"scatter3d","x":[1,2.0],"y":[3,5.0],"z":[5,8.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(134,137,55)"],[1,"rgb(134,137,55)"]],"hoverinfo":"skip","name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.5,"type":"cone","u":[0.5],"v":[1.0],"w":[1.5],"x":[1.937],"y":[4.874],"z":[7.811]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.5,2.5],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.3,"type":"cone","u":[2.5],"v":[0],"w":[0],"x":[2.5],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-0.5,5.5],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.3,"type":"cone","u":[0],"v":[5.5],"w":[0],"x":[0],"y":[5.5],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.8,8.5]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.3,"type":"cone","u":[0],"v":[0],"w":[8.5],"x":[0],"y":[0],"z":[8.5]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444 ...

# %% [markdown]
# #**TRASLACIÓN DE UN VECTORES AL ORIGEN**
#
# #**Traslación en el plano**
#
# Sea $\vec{V}$ el vector del plano que tiene como punto inicial $A = (A_x,A_y)$ y como punto final $B = (B_x,B_y) $ entonces podemos afirmar:
#
# $$\overrightarrow{AB} = (B_x-A_x,B_y- A_y)$$
#
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/vector%20fijo%20-plano.png?raw=true"  height="300" /></center>
#
# ##**Ejemplo:**
# Si $P = (4,2)$ y $Q = (7,6)$ halla las coordenadas del vector $\overrightarrow{PQ}$.

# %%
P = (4,2)
Q = (7,6)

PQ = Matrix([7-4,6-2])
PQ
# Out:
# Matrix([
# [3],
# [4]])

# %% [markdown]
# ## **Representación gráfica de la traslación en el plano**

# %%
plotvectors2D([P,Q],PQ)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="c8757c67-466e-4d7b-aad9-ad19d57cabb2" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c8757c67-466e-4d7b-aad9-ad19d57cabb2")) {                    Plotly.newPlot(                        "c8757c67-466e-4d7b-aad9-ad19d57cabb2",                        [{"marker":{"color":"rgb(167,74,165)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[4,7],"y":[2,6]},{"marker":{"color":"rgb(58,83,64)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[0,3.0],"y":[0,4.0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(167,74,165)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":4,"axref":"x","ay":2,"ayref":"y","showarrow":true,"x":7,"xref":"x","y":6,"yref":"y"},{"arrowcolor":"rgb(58,83,64)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":3.0,"xref":"x","y":4.0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-0.54,"axref":"x","ay":0,"ayref":"y","x":7.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-0.54,"ayref":"y","x":0,"xref":"x","y":6.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.44444444 ...

# %% [markdown]
# #**Traslación en el espacio**
#
# Sea $\vec{V}$ el vector del plano que tiene como punto inicial $A = (A_x,A_y,A_z)$ y como punto final $B = (B_x,B_y,B_z) $ entonces podemos afirmar:
#
# $$\overrightarrow{AB} = (B_x-A_x,B_y-A_y,B_z- A_z)$$
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/vector%20fijo%20-espacio.png?raw=true"  height="300" /></center>
#
# ## **Ejemplo:**
#
# Si $P = (2,3,2)$ y $Q = (3,5,5)$ halla las coordenadas del vector $\vec{PQ}$

# %%
P = (2,3,2)
Q = (3,5,5)

PQ = Matrix([3-2,5-3,5-2])
PQ
# Out:
# Matrix([
# [1],
# [2],
# [3]])

# %% [markdown]
# ## **Representación gráfica de la traslación en el espacio**

# %%
plotvectors3D([P,Q],PQ)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="5fe89256-f0e9-460d-a7e1-28d22be644a3" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5fe89256-f0e9-460d-a7e1-28d22be644a3")) {                    Plotly.newPlot(                        "5fe89256-f0e9-460d-a7e1-28d22be644a3",                        [{"hoverinfo":"name+text","hovertext":"Tail=(2,3,2)\nHead=(3,5,5)","line":{"color":"rgb(192,55,103)","width":7},"marker":{"color":"rgb(192,55,103)","size":1},"name":"vector 1","type":"scatter3d","x":[2,3],"y":[3,5],"z":[2,5]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(192,55,103)"],[1,"rgb(192,55,103)"]],"hoverinfo":"skip","name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.43333333333333335,"type":"cone","u":[0.5],"v":[1.0],"w":[1.5],"x":[2.9937],"y":[4.9874],"z":[4.9811]},{"line":{"color":"rgb(135,129,114)","width":7},"marker":{"color":"rgb(135,129,114)","size":1},"name":"vector 2","type":"scatter3d","x":[0,1.0],"y":[0,2.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(135,129,114)"],[1,"rgb(135,129,114)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.43333333333333335,"type":"cone","u":[1.0],"v":[2.0],"w":[3.0],"x":[1.0],"y":[2.0],"z":[3.0]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.43333333333333335,3.4333333333333336],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.26,"type":"cone","u":[3.4333333333333336],"v":[0],"w":[0],"x":[3.4333333333333336],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-0.43333333333333335,5.433333333333334],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.26,"type":"cone","u":[0],"v":[5.433333333333334],"w":[0],"x":[0],"y":[5.433333333333334],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.7333333333333334,5.433333333333334]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.26,"type":"cone","u":[0],"v":[0],"w":[5.433333333333334],"x":[0],"y":[0],"z":[5.433333333333334]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks" ...

# %% [markdown]
# # **Magnitud, norma o módulo de un vector**
#
# Sea  $\vec{V} \in \mathbb {R^{n}}$ de la forma $\vec{V} = (x_1,x_2 \cdots,x_n)$ el **módulo**, la **norma** o **magnitud** del vector se define y se nota como:
#
# $$||V||= \sqrt{x_1^2+x_2^2+\cdots+x_{n-1}^2+x_{n}^2}$$
#
# Cuando $n\leq 3$ la **norma** conincide con la longitud del vector en su **representación gráfica**.
#
# ##**Ejemplo 1:**
#
# Halla la **norma** del vector representado en la figura:
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/magnitud1.png?raw=true"  height="120" />

# %%
V = Matrix([2])
V.norm()
# Out:
# 2

# %% [markdown]
# ##**Ejemplo 2:**
#
# Halla la **norma** del vector representado en la figura:
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/magnitud2d.png?raw=true"  height="250" />

# %%
V = Matrix([-2,3])
V.norm()
# Out:
# sqrt(13)

# %% [markdown]
# ##**Ejemplo 3:**
#
# Halla la **norma** del vector representado en la figura:
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/magnitud3d.PNG?raw=true"  height="250" />

# %%
V = Matrix([1,2,3])
V.norm()
# Out:
# sqrt(14)

# %% [markdown]
# ##**Ejemplo 4:**
#
# Halla la **norma** del vector
#
# $$\vec{V} = ( 2,4,5,6) $$

# %%
V = Matrix([2,4,5,6])
V.norm()
# Out:
# 9

# %% [markdown]
# #**OPERACIONES CON VECTORES**
# #**ADICIÓN DE VECTORES**
#
# Sean $A,B \in V_n$ tales que $\vec{A} = (A_1,A_2,\cdots, A_n)$ y $\vec{B}= (B_1,B_2,\cdots, B_n)$ vectores en $V_n$ se define la suma analítica de vectores como :
#
# $$\vec{A}+\vec{B} = (A_1 + B_1,A_2+B_2,\cdots,A_n+B_n)$$
#
# Para $n = 1,2,3$ la adición de vectores admite **representación geométrica** y obedece a la *regla del paralelogramo* o *regla del triángulo*.
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/adici%C3%B3n%20vectores.PNG?raw=true"  height="300" /> </center>
#
#
#
# ##**Ejemplo 1:** -----> *adición de vectores bidimensionales*
#
#
# Dados los vectores $\vec{A}= (2,3)$ y  $\vec{B}= (4,2)$  encuentra el vector $A+B$ analíticamente y verifica que la suma cumple la *regla del paralelogramo* geometricamente.

# %% [markdown]
# ## **Adición de los vectores analíticamente**
#
# ### **Forma 1** -----> *como $n$-tuplas*

# %%
A = Matrix([2,3])
B = Matrix([4,2])

A + B
# Out:
# Matrix([
# [6],
# [5]])

# %% [markdown]
# ## **Adición de vectores geométricamente**

# %%
A = Matrix([4,1])
B = Matrix([1,3])
plotvectors2D(A,B,[(4,1),B],A+B)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="dcc5fbf0-2822-4da3-9c15-38f45e954293" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dcc5fbf0-2822-4da3-9c15-38f45e954293")) {                    Plotly.newPlot(                        "dcc5fbf0-2822-4da3-9c15-38f45e954293",                        [{"marker":{"color":"rgb(117,149,63)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[0,4.0],"y":[0,1.0]},{"marker":{"color":"rgb(220,203,214)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[0,1.0],"y":[0,3.0]},{"marker":{"color":"rgb(219,47,97)","size":8},"mode":"lines","name":"vector 3","showlegend":true,"type":"scatter","x":[4,5.0],"y":[1,4.0]},{"marker":{"color":"rgb(82,31,208)","size":8},"mode":"lines","name":"vector 4","showlegend":true,"type":"scatter","x":[0,5.0],"y":[0,4.0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(117,149,63)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":4.0,"xref":"x","y":1.0,"yref":"y"},{"arrowcolor":"rgb(220,203,214)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":1.0,"xref":"x","y":3.0,"yref":"y"},{"arrowcolor":"rgb(219,47,97)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":4,"axref":"x","ay":1,"ayref":"y","showarrow":true,"x":5.0,"xref":"x","y":4.0,"yref":"y"},{"arrowcolor":"rgb(82,31,208)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":5.0,"xref":"x","y":4.0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-0.54,"axref":"x","ay":0,"ayref":"y","x":5.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-0.54,"ayref":"y","x":0,"xref":"x","y":4.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorba ...

# %% [markdown]
# ##**Ejemplo 2:** ------> *adición de vectores unidimensionales*
#
#
# Dados los vectores $\vec{A}= (5)$ y  $\vec{B}= (-3)$  encuentra el vector $A+B$ analíticamente y verifica que la suma cumple la *regla del paralelogramo* geométricamente.

# %% [markdown]
# ## **Adición de los  vectores analíticamente**

# %%
A = Matrix([5])
B = Matrix([-3])

A + B
# Out:
# Matrix([[2]])

# %% [markdown]
# ## **Adición de vectores geométricamente**

# %%
A = Matrix([5])
B = Matrix([-3])

plotvectors2D(A,B,[(-3,0),A],A+B)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="e7ec54ce-baec-4eb0-8fa3-a1a355c16482" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7ec54ce-baec-4eb0-8fa3-a1a355c16482")) {                    Plotly.newPlot(                        "e7ec54ce-baec-4eb0-8fa3-a1a355c16482",                        [{"marker":{"color":"rgb(80,105,203)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[0,5.0],"y":[0,0]},{"marker":{"color":"rgb(8,20,225)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[0,-3.0],"y":[0,0]},{"marker":{"color":"rgb(36,91,123)","size":8},"mode":"lines","name":"vector 3","showlegend":true,"type":"scatter","x":[-3,2.0],"y":[0,0]},{"marker":{"color":"rgb(215,163,95)","size":8},"mode":"lines","name":"vector 4","showlegend":true,"type":"scatter","x":[0,2.0],"y":[0,0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(80,105,203)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":5.0,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"rgb(8,20,225)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":-3.0,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"rgb(36,91,123)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":-3,"axref":"x","ay":0,"ayref":"y","showarrow":true,"x":2.0,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"rgb(215,163,95)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":2.0,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-3.54,"axref":"x","ay":0,"ayref":"y","x":5.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-0.54,"ayref":"y","x":0,"xref":"x","y":0.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidt ...

# %% [markdown]
# ##**Ejemplo 3:** ------> *adición de vectores tridimensionales*
#
# Dados los vectores $\vec{A}= (1,2,3)$ y  $\vec{B}= (5,6,3)$  encuentra el vector $A+B$ analíticamente y verifica que la suma cumple la *regla del paralelogramo* graficamente.

# %% [markdown]
# ## **Adición de los vectores analíticamente**

# %%
A = Matrix([1,2,3])
B = Matrix([5,6,3])

A + B
# Out:
# Matrix([
# [6],
# [8],
# [6]])

# %% [markdown]
# ## **Adición de vectores geométricamente**

# %%
A = Matrix([1,2,3])
B = Matrix([5,6,3])
plotvectors3D(A,B,[(1,2,3),B],A+B)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="b4297fec-1aef-4807-b787-d26025fe9c4d" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4297fec-1aef-4807-b787-d26025fe9c4d")) {                    Plotly.newPlot(                        "b4297fec-1aef-4807-b787-d26025fe9c4d",                        [{"line":{"color":"rgb(36,239,121)","width":7},"marker":{"color":"rgb(36,239,121)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1.0],"y":[0,2.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(36,239,121)"],[1,"rgb(36,239,121)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.6666666666666666,"type":"cone","u":[1.0],"v":[2.0],"w":[3.0],"x":[1.0],"y":[2.0],"z":[3.0]},{"line":{"color":"rgb(155,38,41)","width":7},"marker":{"color":"rgb(155,38,41)","size":1},"name":"vector 2","type":"scatter3d","x":[0,5.0],"y":[0,6.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(155,38,41)"],[1,"rgb(155,38,41)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.6666666666666666,"type":"cone","u":[5.0],"v":[6.0],"w":[3.0],"x":[5.0],"y":[6.0],"z":[3.0]},{"hoverinfo":"name+text","hovertext":"Tail=(1,2,3)\nHead=(6.0,8.0,6.0)","line":{"color":"rgb(8,88,39)","width":7},"marker":{"color":"rgb(8,88,39)","size":1},"name":"vector 3","type":"scatter3d","x":[1,6.0],"y":[2,8.0],"z":[3,6.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(8,88,39)"],[1,"rgb(8,88,39)"]],"hoverinfo":"skip","name":"vector 3","showscale":false,"sizemode":"absolute","sizeref":0.6666666666666666,"type":"cone","u":[2.5],"v":[3.0],"w":[1.5],"x":[5.685],"y":[7.622],"z":[5.811]},{"line":{"color":"rgb(37,177,190)","width":7},"marker":{"color":"rgb(37,177,190)","size":1},"name":"vector 4","type":"scatter3d","x":[0,6.0],"y":[0,8.0],"z":[0,6.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(37,177,190)"],[1,"rgb(37,177,190)"]],"name":"vector 4","showscale":false,"sizemode":"absolute","sizeref":0.6666666666666666,"type":"cone","u":[6.0],"v":[8.0],"w":[6.0],"x":[6.0],"y":[8.0],"z":[6.0]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.6666666666666666,6.666666666666667],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.39999999999999997,"type":"cone","u":[6.666666666666667],"v":[0],"w":[0],"x":[6.666666666666667],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-0.6666666666666666,8.666666666666666],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.39999999999999997,"type":"cone","u":[0],"v":[8.666666666666666],"w":[0],"x":[0],"y":[8.666666666666666],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.9666666666666666,6.666666666666667]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.39999999999999997,"type":" ...

# %% [markdown]
# <p><height="45px" src="<a href="https://ibb.co/pZYMC0T"><img src="https://i.ibb.co/ZL1WsdZ/poll.png" align="left" alt="" width="4%" height="5%"></a><p> <H1><strong>&nbsp;Actividad de práctica</strong>
#
# Dados los puntos  $\vec{A} = (3,2)$,  $\vec{B} = (-5,2)$, $\vec{C} = (-3,-6)$, encuentra analíticamente el vector $\vec{D}$ donde:
#
#  $$ \vec{D} = \vec{A} + \vec{B}+\vec{C}$$
#
#
#
# ¿Qué puedes cuncluir sobre la adición de más de dos vectores de manera geométrica?

# %%
A = Matrix([3,2])
B = Matrix([-5,2])
C = Matrix([-3,-6])
D = A+B+C
D
# Out:
# Matrix([
# [-5],
# [-2]])

# %%
plotvectors2D(A,B,C,[(3,2),B],[(-2,4),C],A+B+C)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="c9dce2d4-5811-421d-937f-6a2a848b77e4" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c9dce2d4-5811-421d-937f-6a2a848b77e4")) {                    Plotly.newPlot(                        "c9dce2d4-5811-421d-937f-6a2a848b77e4",                        [{"marker":{"color":"rgb(74,160,100)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[0,3.0],"y":[0,2.0]},{"marker":{"color":"rgb(75,2,152)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[0,-5.0],"y":[0,2.0]},{"marker":{"color":"rgb(247,86,21)","size":8},"mode":"lines","name":"vector 3","showlegend":true,"type":"scatter","x":[0,-3.0],"y":[0,-6.0]},{"marker":{"color":"rgb(14,17,171)","size":8},"mode":"lines","name":"vector 4","showlegend":true,"type":"scatter","x":[3,-2.0],"y":[2,4.0]},{"marker":{"color":"rgb(246,3,192)","size":8},"mode":"lines","name":"vector 5","showlegend":true,"type":"scatter","x":[-2,-5.0],"y":[4,-2.0]},{"marker":{"color":"rgb(176,170,94)","size":8},"mode":"lines","name":"vector 6","showlegend":true,"type":"scatter","x":[0,-5.0],"y":[0,-2.0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(74,160,100)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":3.0,"xref":"x","y":2.0,"yref":"y"},{"arrowcolor":"rgb(75,2,152)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":-5.0,"xref":"x","y":2.0,"yref":"y"},{"arrowcolor":"rgb(247,86,21)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":-3.0,"xref":"x","y":-6.0,"yref":"y"},{"arrowcolor":"rgb(14,17,171)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":3,"axref":"x","ay":2,"ayref":"y","showarrow":true,"x":-2.0,"xref":"x","y":4.0,"yref":"y"},{"arrowcolor":"rgb(246,3,192)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":-2,"axref":"x","ay":4,"ayref":"y","showarrow":true,"x":-5.0,"xref":"x","y":-2.0,"yref":"y"},{"arrowcolor":"rgb(176,170,94)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":-5.0,"xref":"x","y":-2.0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-5.54,"axref":"x","ay":0,"ayref":"y","x":3.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-6.54,"ayref":"y","x":0,"xref":"x","y":4.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd ...

# %% [markdown]
# #**Propiedades adición de vectores**
#
# Sean los vectores ${\displaystyle A,B,C\in V_n}$,  se cumplen las siguientes propiedades:
# <center>
#
# |            PROPIEDAD           |       EXPLICACIÓN                      |
# |:------------------------------:|:--------------------------------------:|
# | Clausurativa                   |$$A + B \in V_n$$|
# | Conmutativa                     |   $$A + B = B + A$$                      |
# | Asociativa                      |      $$(A +B) + C = A + ( B+C)$$         |
# | Existencia de elemento neutro   |             $$A + 0 = A$$                           |
# | Existencia de inverso aditivo  |     $$A + (-A) = 0 $$ |
# </center>

# %% [markdown]
# #**RESTA DE VECTORES**
#
# Sean $\vec{A},\vec{B} \in V_n$ tales que $\vec{A} = (A_1,A_2,\cdots, A_n)$ y $\vec{B}= (B_1,B_2,\cdots, B_n)$ vectores en $V_n$, se define $\vec{A}-\vec{B} = \vec{A}+(-\vec{B})$, en otras palabras como la adición del vector $\vec{A}$ con el opuesto del vector $\vec{B}$ el cual es $-\vec{B}= (-B_1,-B_2,\cdots, -B_n)$, vector que posee la misma magnitud y dirección del $\vec{B}$ pero sentido opuesto, luego tenemos que:
#
# $$\vec{A}-\vec{B} = (A_1 - B_1,A_2-B_2,\cdots,A_n-B_n)$$
#
#
# Para $n = 1,2,3$ la resta de vectores admite una interpretación y **representación geométrica**.
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/resta%20vectores.PNG?raw=true"  height="300" /> </center>
#
#
#
#
# ##**Ejemplo 1:** -----> *resta de vectores bidimensionales*
#
# Dados los vectores $\vec{A}= (2,3)$ y  $\vec{B}= (4,2)$  encuentra el vector $A-B$ analíticamente y verifica que la resta con una representación gráfica.
#
# ## **Resta de los vectores analíticamente**

# %%
A = Matrix([3,1])
B = Matrix([1,2])
A - B
# Out:
# Matrix([
# [ 2],
# [-1]])

# %% [markdown]
# ## **Resta de vectores geométricamente**

# %%
plotvectors2D(A,B,A-B,[(1,2),A-B])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="a46e43d8-0d0b-4f9e-bc8d-201cd5c39542" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a46e43d8-0d0b-4f9e-bc8d-201cd5c39542")) {                    Plotly.newPlot(                        "a46e43d8-0d0b-4f9e-bc8d-201cd5c39542",                        [{"marker":{"color":"rgb(58,7,248)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[0,3.0],"y":[0,1.0]},{"marker":{"color":"rgb(201,117,137)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[0,1.0],"y":[0,2.0]},{"marker":{"color":"rgb(41,46,102)","size":8},"mode":"lines","name":"vector 3","showlegend":true,"type":"scatter","x":[0,2.0],"y":[0,-1.0]},{"marker":{"color":"rgb(190,111,254)","size":8},"mode":"lines","name":"vector 4","showlegend":true,"type":"scatter","x":[1,3.0],"y":[2,1.0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(58,7,248)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":3.0,"xref":"x","y":1.0,"yref":"y"},{"arrowcolor":"rgb(201,117,137)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":1.0,"xref":"x","y":2.0,"yref":"y"},{"arrowcolor":"rgb(41,46,102)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":2.0,"xref":"x","y":-1.0,"yref":"y"},{"arrowcolor":"rgb(190,111,254)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":1,"axref":"x","ay":2,"ayref":"y","showarrow":true,"x":3.0,"xref":"x","y":1.0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-0.54,"axref":"x","ay":0,"ayref":"y","x":3.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-1.54,"ayref":"y","x":0,"xref":"x","y":2.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"color ...

# %% [markdown]
# ##**Ejemplo 2:** ------> *resta de vectores tridimensionales*
#
# Dados los vectores $\vec{A}= (1,2,3)$ y  $\vec{B}= (5,6,3)$  encuentra el vector $A+B$ analíticamente y verifica que la suma cumple la *regla del paralelogramo* graficamente.

# %% [markdown]
# ## **Resta de los vectores analíticamente**

# %%
A = Matrix([1,2,3])
B = Matrix([5,6,3])

A - B
# Out:
# Matrix([
# [-4],
# [-4],
# [ 0]])

# %% [markdown]
# ## **Resta de vectores geométricamente**

# %%
A = Matrix([1,2,3])
B = Matrix([5,6,3])

plotvectors3D(A,B,A-B,[(5,6,3),A-B])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="1050da64-b9bc-44ac-bc8d-586342dd3ceb" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1050da64-b9bc-44ac-bc8d-586342dd3ceb")) {                    Plotly.newPlot(                        "1050da64-b9bc-44ac-bc8d-586342dd3ceb",                        [{"line":{"color":"rgb(180,173,185)","width":7},"marker":{"color":"rgb(180,173,185)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1.0],"y":[0,2.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(180,173,185)"],[1,"rgb(180,173,185)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.4666666666666667,"type":"cone","u":[1.0],"v":[2.0],"w":[3.0],"x":[1.0],"y":[2.0],"z":[3.0]},{"line":{"color":"rgb(70,85,164)","width":7},"marker":{"color":"rgb(70,85,164)","size":1},"name":"vector 2","type":"scatter3d","x":[0,5.0],"y":[0,6.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(70,85,164)"],[1,"rgb(70,85,164)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.4666666666666667,"type":"cone","u":[5.0],"v":[6.0],"w":[3.0],"x":[5.0],"y":[6.0],"z":[3.0]},{"line":{"color":"rgb(135,180,203)","width":7},"marker":{"color":"rgb(135,180,203)","size":1},"name":"vector 3","type":"scatter3d","x":[0,-4.0],"y":[0,-4.0],"z":[0,0.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(135,180,203)"],[1,"rgb(135,180,203)"]],"name":"vector 3","showscale":false,"sizemode":"absolute","sizeref":0.4666666666666667,"type":"cone","u":[-4.0],"v":[-4.0],"w":[0.0],"x":[-4.0],"y":[-4.0],"z":[0.0]},{"hoverinfo":"name+text","hovertext":"Tail=(5,6,3)\nHead=(1.0,2.0,3.0)","line":{"color":"rgb(39,93,82)","width":7},"marker":{"color":"rgb(39,93,82)","size":1},"name":"vector 4","type":"scatter3d","x":[5,1.0],"y":[6,2.0],"z":[3,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(39,93,82)"],[1,"rgb(39,93,82)"]],"hoverinfo":"skip","name":"vector 4","showscale":false,"sizemode":"absolute","sizeref":0.4666666666666667,"type":"cone","u":[-2.0],"v":[-2.0],"w":[0.0],"x":[1.252],"y":[2.252],"z":[3.0]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-4.466666666666667,5.466666666666667],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.27999999999999997,"type":"cone","u":[5.466666666666667],"v":[0],"w":[0],"x":[5.466666666666667],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-4.466666666666667,6.466666666666667],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.27999999999999997,"type":"cone","u":[0],"v":[6.466666666666667],"w":[0],"x":[0],"y":[6.466666666666667],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.7666666666666666,3.466666666666667]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.2799999999 ...

# %% [markdown]
# #**MULTIPLICACIÓN POR UN ESCALAR**
#
# Sean $\vec{A}\in V_n$ y $K \in \mathbb{R}$ tal que $\vec{A} = (A_1,A_2,\cdots, A_n)$, se define $k\vec{A}$ cómo :
#
# $$k\vec{A} = \underbrace{\vec{A}+ \vec{A} \cdots+ \vec{A}}_{k \ \text{veces}}$$
#
# De lo cual se deduce que:
#
# $$k\vec{A} = (kA_1,kA_2,\cdots,kA_n)$$
#
#
#
# Para $n = 1,2,3$ la multiplicación de un vector por un escalar admite una interpretación y **representación geométrica**.
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/multiplicaci%C3%B3n%20por%20escalar.PNG?raw=true"  height="300" /> </center>
#
#
#
# ##**Ejemplo:**
#
# Dados los vectores $\vec{A}= (2,4)$ encuentra el vectores $2A$, $\frac{1}{2}A$, $-2A$, $-\frac{1}{2}A$ analíticamente y realiza su representación gráfica en el mismo plano.¿Qué puedes concluir si $-1<k<1$ o si $k<-1$ o $1<k$?
#
# ## **Multiplicación por un escalar de los vectores analíticamente**

# %%
A = Matrix([2,4])
A
# Out:
# Matrix([
# [2],
# [4]])

# %%
-2*A
# Out:
# Matrix([
# [-4],
# [-8]])

# %%
(1/2)*A
# Out:
# Matrix([
# [1.0],
# [2.0]])

# %%
(-1/2)*A
# Out:
# Matrix([
# [-1.0],
# [-2.0]])

# %% [markdown]
# ## **Representación gráfica de los vectores en el plano**

# %%
plotvectors2D(A,2*A,(1/2)*A,-2*A,(-1/2)*A)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="5b233e9f-5101-4fed-a9b8-b2a0a0d12b90" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b233e9f-5101-4fed-a9b8-b2a0a0d12b90")) {                    Plotly.newPlot(                        "5b233e9f-5101-4fed-a9b8-b2a0a0d12b90",                        [{"marker":{"color":"rgb(216,26,227)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[0,2.0],"y":[0,4.0]},{"marker":{"color":"rgb(216,2,85)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[0,4.0],"y":[0,8.0]},{"marker":{"color":"rgb(216,104,72)","size":8},"mode":"lines","name":"vector 3","showlegend":true,"type":"scatter","x":[0,1.0],"y":[0,2.0]},{"marker":{"color":"rgb(106,170,56)","size":8},"mode":"lines","name":"vector 4","showlegend":true,"type":"scatter","x":[0,-4.0],"y":[0,-8.0]},{"marker":{"color":"rgb(69,0,219)","size":8},"mode":"lines","name":"vector 5","showlegend":true,"type":"scatter","x":[0,-1.0],"y":[0,-2.0]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(216,26,227)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":2.0,"xref":"x","y":4.0,"yref":"y"},{"arrowcolor":"rgb(216,2,85)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":4.0,"xref":"x","y":8.0,"yref":"y"},{"arrowcolor":"rgb(216,104,72)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":1.0,"xref":"x","y":2.0,"yref":"y"},{"arrowcolor":"rgb(106,170,56)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":-4.0,"xref":"x","y":-8.0,"yref":"y"},{"arrowcolor":"rgb(69,0,219)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":-1.0,"xref":"x","y":-2.0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-4.54,"axref":"x","ay":0,"ayref":"y","x":4.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-8.54,"ayref":"y","x":0,"xref":"x","y":8.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale": ...

# %% [markdown]
# #**VECTOR UNITARIO Y VERSOR**
#
# Si $\vec{V} \in V_n$ es un vector tal que $\,|\vert \vec{V} \,|\vert = 1$ entonces el $\vec{V}$ recibe el nombre de **vector unitario** y se nota con acento circunflejo como $\hat{V}$.
#
#
# El vector unitario $\hat{V}$ o $\vec{U}_V$ asociado al vector $\vec{V}$ y que posee la misma dirección y sentido del vector $\vec{V}$  se llama **versor** asociado a  $\vec{V}$, la operación que permite encontarlo es:
#
# $$\hat{V} = \dfrac{1}{\,|\vert \vec{V} \,|\vert}\vec{V}$$
#
# ##**Ejemplo 1:**
#
# Hallar el vector unitario  $\vec{U}_V$ asociado al vector $\vec{V}= (4,3)$ y verifica tu resultado encontrando $\,|\vert \vec{U}_V \,|\vert$ y realizando la grafica de $\vec{U}_V$ y  $\vec{V}$ en el mismo plano.

# %%
V = Matrix([4,3])
U_v = (1/(V.norm()))*V
U_v
# Out:
# Matrix([
# [4/5],
# [3/5]])

# %%
U_v.norm()
# Out:
# 1

# %%
plotvectors2D(V,U_v)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="bc21f558-10df-4b73-a708-23bd5a69d40e" class="plotly-graph-div" style="height:480px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bc21f558-10df-4b73-a708-23bd5a69d40e")) {                    Plotly.newPlot(                        "bc21f558-10df-4b73-a708-23bd5a69d40e",                        [{"marker":{"color":"rgb(67,244,173)","size":8},"mode":"lines","name":"vector 1","showlegend":true,"type":"scatter","x":[0,4.0],"y":[0,3.0]},{"marker":{"color":"rgb(198,16,224)","size":8},"mode":"lines","name":"vector 2","showlegend":true,"type":"scatter","x":[0,0.8],"y":[0,0.6]},{"marker":{"color":"#2a3f5f","size":9},"mode":"markers","name":"origen","opacity":1,"showlegend":true,"type":"scatter","x":[0],"y":[0]}],                        {"annotations":[{"arrowcolor":"rgb(67,244,173)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":4.0,"xref":"x","y":3.0,"yref":"y"},{"arrowcolor":"rgb(198,16,224)","arrowhead":2,"arrowsize":1.5,"arrowwidth":2.3,"ax":0.0,"axref":"x","ay":0.0,"ayref":"y","showarrow":true,"x":0.8,"xref":"x","y":0.6,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":-0.54,"axref":"x","ay":0,"ayref":"y","x":4.5,"xref":"x","y":0,"yref":"y"},{"arrowcolor":"#2a3f5f","arrowhead":2,"arrowwidth":1.5,"ax":0,"axref":"x","ay":-0.54,"ayref":"y","x":0,"xref":"x","y":3.5,"yref":"y"}],"font":{"color":"black","family":"latex","size":20},"height":480,"legend":{"itemdoubleclick":"toggle","orientation":"h","x":1,"xanchor":"right","y":1.02,"yanchor":"bottom"},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c17 ...

# %% [markdown]
# <p><height="45px" src="<a href="https://ibb.co/pZYMC0T"><img src="https://i.ibb.co/ZL1WsdZ/poll.png" align="left" alt="" width="4%" height="5%"></a><p> <H1><strong>&nbsp;Actividad de práctica</strong>
#
# Encuentra un vector $\vec{A}$ tal que $\,|\vert \vec{A} \,|\vert = 10$   y tenga la misma dirección y sentidol vector  $\vec{V}= (4,3)$.

# %% [markdown]
# <p><height="45px" src="<a href="https://ibb.co/pZYMC0T"><img src="https://i.ibb.co/ZL1WsdZ/poll.png" align="left" alt="" width="4%" height="5%"></a><p> <H1><strong>&nbsp;Actividad de práctica</strong>
#
# Encuentra un vector unitario en la dirección del eje $x$ y hacia el sentido positivo, un vector unitario en la dirección del eje $y$ y hacia el sentido positivo, siendo $a =2$ y $b =3$ encuentra el vector $a\hat{\imath}$ y $b\hat{\jmath}$,  luego realiza la adición $a\hat{\imath} + b\hat{\imath}$ y compara este resultado con el $\vec{V}=(a,b)$ y  realiza la grafica de los vectores anteriores en el mismo plano.¿Qué puedes concluir de lo anterior?

# %%
a = 2
b = 3

i = 
j =

V = Matrix([4,3])

# %% [markdown]
# #**PRODUCTO PUNTO O PRODUCTO ESCALAR**
#
# Sean $\vec{A},\vec{B}\in V_n$ tal que $\vec{A} = (A_1,A_2,\cdots, A_n)$ y $\vec{B} = (B_1,B_2,\cdots, B_n)$ se define el **producto punto o producto escalar** como la suma de los productos de las correspondientes componentes de los vectores,
# <br/><br/>
#
# $$ \vec{A}\cdot \vec{B} = A_1B_1+A_2B_2+A_3B_3+ \cdots +A_nB_n$$
#
#
#
# ##**Ejemplo:**
#
# Dados el vector $\vec{A}= (5,3,-1)$  y $\vec{B}= (-2,-1,6)$ encuentra el producto $\vec{A}\cdot \vec{B}$ .

# %%
A = Matrix([5,3,-1])
B = Matrix([-2,-1,6])

A.dot(B)
# Out:
# -19

# %% [markdown]
# #**Propiedades producto escalar de vectores**
#
# Sean los vectores ${\displaystyle \vec{A},\vec{B},\vec{C}\in V_n}$ y $k \in \mathbb{R}$, se cumplen las siguientes propiedades relacionadas con el producto escalar:
#
# <center>
#
# |            PROPIEDAD           |       EXPLICACIÓN                      |
# |:------------------------------:|:--------------------------------------:|
# | Producto de un vector por si mismo                   |$$ \vec{A} \cdot \vec{A} =\,|\vert \vec{A} \,|\vert^{2}$$|
# | Conmutativa                     |   $$\vec{A} \cdot \vec{B} = \vec{B} \cdot \vec{A}$$                      |
# | Asociativa                      |      $$k(\vec{A} \cdot \vec{C}) = (k\vec{A})\cdot \vec{B} =\vec{A}\cdot(k\vec{B})$$         |
# | Producto con el vector nulo  |             $$\vec{A} \cdot \vec{0}=0$$                           |
# | Distributiva respecto a la suma de vectores  |     $$\vec{A} \cdot(\vec{B}+\vec{C}) = \vec{A}\cdot \vec{B} +\vec{A}\cdot \vec{C} $$                                  |
# </center>

# %% [markdown]
# #**APLICACIONES PRODUCTO ESCALAR**
#
# #**Angulo entre vectores**
#
# Sean ${\displaystyle \vec{A},\vec{B}\in V_n}$ tal que $n = 1,2,3$ y admiten representación geométrica, se define $θ$  como el ángulo no negativo más pequeño entre $ \vec{A}$  y $ \vec{B}$, la expresión para calcular  $θ$ es:
#
# $$θ = cos^{-1}{\left(\dfrac{\vec{A} \cdot\vec{B}}{\,|\vert \vec{A} \,|\vert\,|\vert \vec{B} \,|\vert}\right)}$$ \\
#
# Si  $\vec{A} \cdot\vec{B} > 0$ entonces $θ$ es un **ángulo agudo**, Si  $\vec{A} \cdot\vec{B} < 0$ entonces $θ$ es un **ángulo obtuso**
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/angulovector.PNG?raw=true"  height="250" /> </center>
#
# ##**Ejemplo:**
#
# Dados el vector $\vec{A}= (2,1,-1)$  y $\vec{B}= (1,-1,1)$ encuentra el ángulo determinado por los vectores $\vec{A}$  y $\vec{B}$ y realiza la gráfica de los dos vectores en el mismo espacio.

# %%
A = Matrix([2,1,-1])
B = Matrix([1,-1,1])

angulo = acos(A.dot(B)/(A.norm()*B.norm()))
angulo
# Out:
# pi/2

# %%
plotvectors3D(A,B)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="23ab33fe-583b-4058-a334-33f3b57de900" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("23ab33fe-583b-4058-a334-33f3b57de900")) {                    Plotly.newPlot(                        "23ab33fe-583b-4058-a334-33f3b57de900",                        [{"line":{"color":"rgb(64,234,27)","width":7},"marker":{"color":"rgb(64,234,27)","size":1},"name":"vector 1","type":"scatter3d","x":[0,2.0],"y":[0,1.0],"z":[0,-1.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(64,234,27)"],[1,"rgb(64,234,27)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.13333333333333333,"type":"cone","u":[2.0],"v":[1.0],"w":[-1.0],"x":[2.0],"y":[1.0],"z":[-1.0]},{"line":{"color":"rgb(20,26,56)","width":7},"marker":{"color":"rgb(20,26,56)","size":1},"name":"vector 2","type":"scatter3d","x":[0,1.0],"y":[0,-1.0],"z":[0,1.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(20,26,56)"],[1,"rgb(20,26,56)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.13333333333333333,"type":"cone","u":[1.0],"v":[-1.0],"w":[1.0],"x":[1.0],"y":[-1.0],"z":[1.0]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.13333333333333333,2.1333333333333333],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.08,"type":"cone","u":[2.1333333333333333],"v":[0],"w":[0],"x":[2.1333333333333333],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-1.1333333333333333,1.1333333333333333],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.08,"type":"cone","u":[0],"v":[1.1333333333333333],"w":[0],"x":[0],"y":[1.1333333333333333],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-1.1333333333333333,1.1333333333333333]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.08,"type":"cone","u":[0],"v":[0],"w":[1.1333333333333333],"x":[0],"y":[0],"z":[1.1333333333333333]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale" ...

# %% [markdown]
# #**Vectores paralelos**
#
# Dos vectores ${\displaystyle \vec{A},\vec{B}\in V_n}$ donde $n =1,2 \ \text{o}\ 3$ son paralelos, si tienen la misma dirección o el ángulo que forman es de 0 radianes (0 grados) o de $π$ radianes (180 grados).
#
# Dos vectores ${\displaystyle \vec{A},\vec{B}\in V_n}$ son paralelos si exite una constante $k$ tal que  $\vec{B} =k \vec{A} $  o  $ \vec{A} =k \vec{B}$.
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/vectores%20paralelos.PNG?raw=true"  height="250" /> </center>
#
# ##**Ejemplo:**
#
# Dados el vector $\vec{A}= (1,-2,3)$  y $\vec{B}= (-2,4,-6)$ determina si los vectores son paralelos y si lo son encuentra el valor de una constante $k$ tal que $\vec{A} =k \vec{B}$, realiza la gráfica de los vectores en el mismo espacio.

# %%
A = Matrix([1,-2,3])
B = Matrix([-2,4,-6])

angulo = acos(A.dot(B)/(A.norm()*B.norm()))
angulo
# Out:
# pi

# %%
plotvectors3D(A,B)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="6df73f10-e128-46a0-883f-c1bd803c712b" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6df73f10-e128-46a0-883f-c1bd803c712b")) {                    Plotly.newPlot(                        "6df73f10-e128-46a0-883f-c1bd803c712b",                        [{"line":{"color":"rgb(110,60,189)","width":7},"marker":{"color":"rgb(110,60,189)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1.0],"y":[0,-2.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(110,60,189)"],[1,"rgb(110,60,189)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.26666666666666666,"type":"cone","u":[1.0],"v":[-2.0],"w":[3.0],"x":[1.0],"y":[-2.0],"z":[3.0]},{"line":{"color":"rgb(247,115,164)","width":7},"marker":{"color":"rgb(247,115,164)","size":1},"name":"vector 2","type":"scatter3d","x":[0,-2.0],"y":[0,4.0],"z":[0,-6.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(247,115,164)"],[1,"rgb(247,115,164)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.26666666666666666,"type":"cone","u":[-2.0],"v":[4.0],"w":[-6.0],"x":[-2.0],"y":[4.0],"z":[-6.0]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-2.2666666666666666,1.2666666666666666],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.16,"type":"cone","u":[1.2666666666666666],"v":[0],"w":[0],"x":[1.2666666666666666],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-2.2666666666666666,4.266666666666667],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.16,"type":"cone","u":[0],"v":[4.266666666666667],"w":[0],"x":[0],"y":[4.266666666666667],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-6.266666666666667,3.2666666666666666]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.16,"type":"cone","u":[0],"v":[0],"w":[3.2666666666666666],"x":[0],"y":[0],"z":[3.2666666666666666]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":"" ...

# %% [markdown]
# #**Vectores ortogonales**
#
# Dos vectores ${\displaystyle \vec{A},\vec{B}\in V_n}$ donde $n =1,2 \ \text{o}\ 3$  son **ortogonanales o perpendiculares** cuando forman ángulo recto entre sí.
#
# Dos vectores ${\displaystyle \vec{A},\vec{B}\in V_n}$ son ortogonales si
# $\vec{A} \cdot \vec{B} =0$.
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/perpendiculares.PNG?raw=true"  height="250" /> </center>
#
# ##**Ejemplo:**
#
# Dados el vector $\vec{A}= (2,1,-1)$  y $\vec{B}= (1,-1,1)$ determina si los vectores son **ortogonales** y realiza la gáfica de los dos vectores en el mismo espacio.

# %%
A = Matrix([2,1,-1])
B = Matrix([1,-1,1])

A.dot(B)
# Out:
# 0

# %%
plotvectors3D(A,B)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="cd603a3e-947c-48f1-b30d-422f59f70d03" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cd603a3e-947c-48f1-b30d-422f59f70d03")) {                    Plotly.newPlot(                        "cd603a3e-947c-48f1-b30d-422f59f70d03",                        [{"line":{"color":"rgb(166,229,165)","width":7},"marker":{"color":"rgb(166,229,165)","size":1},"name":"vector 1","type":"scatter3d","x":[0,2.0],"y":[0,1.0],"z":[0,-1.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(166,229,165)"],[1,"rgb(166,229,165)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.13333333333333333,"type":"cone","u":[2.0],"v":[1.0],"w":[-1.0],"x":[2.0],"y":[1.0],"z":[-1.0]},{"line":{"color":"rgb(71,30,14)","width":7},"marker":{"color":"rgb(71,30,14)","size":1},"name":"vector 2","type":"scatter3d","x":[0,1.0],"y":[0,-1.0],"z":[0,1.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(71,30,14)"],[1,"rgb(71,30,14)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.13333333333333333,"type":"cone","u":[1.0],"v":[-1.0],"w":[1.0],"x":[1.0],"y":[-1.0],"z":[1.0]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.13333333333333333,2.1333333333333333],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.08,"type":"cone","u":[2.1333333333333333],"v":[0],"w":[0],"x":[2.1333333333333333],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-1.1333333333333333,1.1333333333333333],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.08,"type":"cone","u":[0],"v":[1.1333333333333333],"w":[0],"x":[0],"y":[1.1333333333333333],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-1.1333333333333333,1.1333333333333333]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.08,"type":"cone","u":[0],"v":[0],"w":[1.1333333333333333],"x":[0],"y":[0],"z":[1.1333333333333333]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"col ...

# %% [markdown]
# #**Proyección ortogonal**
#
# Sean ${\displaystyle \vec{U},\vec{V}\in V_n}$ dos vectores diferentes de cero. Entonces la proyección de $\vec{U}$ sobre $\vec{V}$ es un vector denotado por $\text{proy}_\vec{V} \vec{U}$, que se define con la siguiente expresión:
#
# $$\text{proy}_\vec{V} \vec{U} = \left(\dfrac{\vec{U} \cdot\vec{V} }{||\vec{V}||^2} \right)\vec{V}$$\\
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/proyecci%C3%B3n.PNG?raw=true"  height="250" /> </center>
#
# ##**Ejemplo:**
#
# Dados el vector $\vec{A}= (2,3,1)$  y $\vec{B}= (3,4,5)$ determina la proyección del vector $\vec{A}$ sobre $\vec{B}$ y realiza la grafica de los tres vectores en el mismo espacio.

# %%
A = Matrix([2,3,1])
B = Matrix([3,4,5])

proyAB =(A.dot(B)/(B.norm())**2)*B
proyAB
# Out:
# Matrix([
# [69/50],
# [46/25],
# [23/10]])

# %%
plotvectors3D(A,B,proyAB)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="e0c4107d-582a-4528-a01e-f7cf0154f2eb" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e0c4107d-582a-4528-a01e-f7cf0154f2eb")) {                    Plotly.newPlot(                        "e0c4107d-582a-4528-a01e-f7cf0154f2eb",                        [{"line":{"color":"rgb(98,5,52)","width":7},"marker":{"color":"rgb(98,5,52)","size":1},"name":"vector 1","type":"scatter3d","x":[0,2.0],"y":[0,3.0],"z":[0,1.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(98,5,52)"],[1,"rgb(98,5,52)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.4,"type":"cone","u":[2.0],"v":[3.0],"w":[1.0],"x":[2.0],"y":[3.0],"z":[1.0]},{"line":{"color":"rgb(137,132,79)","width":7},"marker":{"color":"rgb(137,132,79)","size":1},"name":"vector 2","type":"scatter3d","x":[0,3.0],"y":[0,4.0],"z":[0,5.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(137,132,79)"],[1,"rgb(137,132,79)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.4,"type":"cone","u":[3.0],"v":[4.0],"w":[5.0],"x":[3.0],"y":[4.0],"z":[5.0]},{"line":{"color":"rgb(238,205,46)","width":7},"marker":{"color":"rgb(238,205,46)","size":1},"name":"vector 3","type":"scatter3d","x":[0,1.38],"y":[0,1.84],"z":[0,2.3]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(238,205,46)"],[1,"rgb(238,205,46)"]],"name":"vector 3","showscale":false,"sizemode":"absolute","sizeref":0.4,"type":"cone","u":[1.38],"v":[1.84],"w":[2.3],"x":[1.38],"y":[1.84],"z":[2.3]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.4,3.4],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.24,"type":"cone","u":[3.4],"v":[0],"w":[0],"x":[3.4],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-0.4,4.4],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.24,"type":"cone","u":[0],"v":[4.4],"w":[0],"x":[0],"y":[4.4],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.7,5.4]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.24,"type":"cone","u":[0],"v":[0],"w":[5.4],"x":[0],"y":[0],"z":[5.4]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white", ...

# %% [markdown]
# #**PRODUCTO CRUZ O PRODUCTO VECTORIAL**
#
# Sean $\vec{A},\vec{B}\in V_3$ tal que $\vec{A} = (A_1,A_2,A_3)$ y $\vec{B} = (B_1,B_2,B_3)$ se define el **producto cruz o producto vectorial** como:
#
# <br>
#
# $$ \vec{A}\times \vec{B} = \left|\begin{array}{ccc}
# \hat{i} & \hat{j}&\hat{k}\\
# A_1 & A_2 & A_3 \\
# B_1 & B_2 & B_3
# \end{array} \right| = (A_2B_3-A_3B_2)\hat{i} -  (A_1B_3-A_3B_1)\hat{j} +(A_1B_2-A_2B_1)\hat{k}  $$
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/productocruz.PNG?raw=true"  height="250" /> </center>
#
# ##**Ejemplo:**
#
# Dados el vector $\vec{A}= (1,2,3)$  y $\vec{B}= (-5,4,8)$ encuentra el vector $\vec{A} \times \vec{B}$ y verifica este producto graficamente.

# %%
A = Matrix([1,2,3])
B = Matrix([-5,4,8])

A.cross(B)
# Out:
# Matrix([
# [  4],
# [-23],
# [ 14]])

# %%
B.cross(A)
# Out:
# Matrix([
# [ -4],
# [ 23],
# [-14]])

# %%
A = Matrix([1,2,3])
B = Matrix([-4,2,1])

plotvectors3D(A,B,A.cross(B))
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="5bdc9d45-5be3-4c41-a6db-f6efe2a7f62d" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5bdc9d45-5be3-4c41-a6db-f6efe2a7f62d")) {                    Plotly.newPlot(                        "5bdc9d45-5be3-4c41-a6db-f6efe2a7f62d",                        [{"line":{"color":"rgb(31,245,243)","width":7},"marker":{"color":"rgb(31,245,243)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1.0],"y":[0,2.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(31,245,243)"],[1,"rgb(31,245,243)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.43333333333333335,"type":"cone","u":[1.0],"v":[2.0],"w":[3.0],"x":[1.0],"y":[2.0],"z":[3.0]},{"line":{"color":"rgb(106,250,165)","width":7},"marker":{"color":"rgb(106,250,165)","size":1},"name":"vector 2","type":"scatter3d","x":[0,-4.0],"y":[0,2.0],"z":[0,1.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(106,250,165)"],[1,"rgb(106,250,165)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.43333333333333335,"type":"cone","u":[-4.0],"v":[2.0],"w":[1.0],"x":[-4.0],"y":[2.0],"z":[1.0]},{"line":{"color":"rgb(94,14,242)","width":7},"marker":{"color":"rgb(94,14,242)","size":1},"name":"vector 3","type":"scatter3d","x":[0,-4.0],"y":[0,-13.0],"z":[0,10.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(94,14,242)"],[1,"rgb(94,14,242)"]],"name":"vector 3","showscale":false,"sizemode":"absolute","sizeref":0.43333333333333335,"type":"cone","u":[-4.0],"v":[-13.0],"w":[10.0],"x":[-4.0],"y":[-13.0],"z":[10.0]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-4.433333333333334,1.4333333333333333],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.26,"type":"cone","u":[1.4333333333333333],"v":[0],"w":[0],"x":[1.4333333333333333],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-13.433333333333334,2.4333333333333336],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.26,"type":"cone","u":[0],"v":[2.4333333333333336],"w":[0],"x":[0],"y":[2.4333333333333336],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.7333333333333334,10.433333333333334]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.26,"type":"cone","u":[0],"v":[0],"w":[10.433333333333334],"x":[0],"y":[0],"z":[10.433333333333334]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10," ...

# %% [markdown]
# #**Propiedades producto vectorial de vectores**
#
# Sean los vectores ${\displaystyle \vec{A},\vec{B},\vec{C}\in V_3}$ y $k \in \mathbb{R}$, se cumplen las siguientes propiedades relacionadas con el producto vectorial:
#
# <center>
#
# |            PROPIEDAD           |       EXPLICACIÓN                      |
# |:------------------------------:|:--------------------------------------:|
# | Propiedad anticonmutativa                   |$$ \vec{A} \times \vec{B} =-( \vec{B} \times \vec{A})$$|
# | Asociativa                      |      $$k(\vec{A} \times \vec{C}) = (k\vec{A})\times \vec{B} =\vec{A}\times(k\vec{B})$$         |
# | Producto con el vector nulo  |             $$\vec{A} \times \vec{0}= \vec{0} \times \vec{A}=\vec{0}$$                           |
# | Distributiva respecto a la suma de vectores  |     $$\vec{A} \times(\vec{B}+\vec{C}) = \vec{A}\times \vec{B} +\vec{A}\times \vec{C} $$                                  |
# | Asociativa producto triple  |     $$\vec{A} \cdot (\vec{B}\times\vec{C}) = (\vec{A}\times \vec{B}) \cdot \vec{C} $$                                  |
# </center>

# %% [markdown]
# #**APLICACIONES PRODUCTO VECTORIAL**
#
# #**Area del paralelogramo**
#
# Dados los vectores ${\displaystyle \vec{U},\vec{V}\in V_3}$ si el ángulo entre ellos es $θ$, la magnitud del producto vectorial entre estos dos vectores la podemos expresar como:
#
# $$||\vec{U}\times\vec{V}|| = ||\vec{U}||  ||\vec{V}|| \sin{θ}$$
# <br>
#
# Luego  se puede afirmar desde la representación geométrica que $||\vec{U}\times\vec{V}||$ es el área del paralelogramo determinado por  $\vec{U}$ y $\vec{V}$
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/areaparalelogramo.PNG?raw=true"  height="250" /> </center>
#
# ##**Ejemplo:**
# Dados el vector $\vec{A}= (1,2,3)$  y $\vec{B}= (4,5,6)$ realiza su gáfica y cálcula el area del paralelogramo determinado por estos dos vectores.

# %%
A = Matrix([1,2,3])
B = Matrix([2,-3,4])

A.cross(B).norm()
# Out:
# 3*sqrt(38)

# %%
plotvectors3D(A,B,[(2,-3,4),A],[(1,2,3),B])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="fde6afbd-c3b3-44c9-87a6-52cbaac20245" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fde6afbd-c3b3-44c9-87a6-52cbaac20245")) {                    Plotly.newPlot(                        "fde6afbd-c3b3-44c9-87a6-52cbaac20245",                        [{"line":{"color":"rgb(55,31,68)","width":7},"marker":{"color":"rgb(55,31,68)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1.0],"y":[0,2.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(55,31,68)"],[1,"rgb(55,31,68)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.4,"type":"cone","u":[1.0],"v":[2.0],"w":[3.0],"x":[1.0],"y":[2.0],"z":[3.0]},{"line":{"color":"rgb(209,120,195)","width":7},"marker":{"color":"rgb(209,120,195)","size":1},"name":"vector 2","type":"scatter3d","x":[0,2.0],"y":[0,-3.0],"z":[0,4.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(209,120,195)"],[1,"rgb(209,120,195)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.4,"type":"cone","u":[2.0],"v":[-3.0],"w":[4.0],"x":[2.0],"y":[-3.0],"z":[4.0]},{"hoverinfo":"name+text","hovertext":"Tail=(2,-3,4)\nHead=(3.0,-1.0,7.0)","line":{"color":"rgb(235,69,116)","width":7},"marker":{"color":"rgb(235,69,116)","size":1},"name":"vector 3","type":"scatter3d","x":[2,3.0],"y":[-3,-1.0],"z":[4,7.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(235,69,116)"],[1,"rgb(235,69,116)"]],"hoverinfo":"skip","name":"vector 3","showscale":false,"sizemode":"absolute","sizeref":0.4,"type":"cone","u":[0.5],"v":[1.0],"w":[1.5],"x":[2.937],"y":[-1.126],"z":[6.811]},{"hoverinfo":"name+text","hovertext":"Tail=(1,2,3)\nHead=(3.0,-1.0,7.0)","line":{"color":"rgb(209,207,186)","width":7},"marker":{"color":"rgb(209,207,186)","size":1},"name":"vector 4","type":"scatter3d","x":[1,3.0],"y":[2,-1.0],"z":[3,7.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(209,207,186)"],[1,"rgb(209,207,186)"]],"hoverinfo":"skip","name":"vector 4","showscale":false,"sizemode":"absolute","sizeref":0.4,"type":"cone","u":[1.0],"v":[-1.5],"w":[2.0],"x":[2.874],"y":[-0.8109999999999999],"z":[6.748]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-0.4,3.4],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.24,"type":"cone","u":[3.4],"v":[0],"w":[0],"x":[3.4],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-3.4,2.4],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.24,"type":"cone","u":[0],"v":[2.4],"w":[0],"x":[0],"y":[2.4],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-0.7,7.4]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.24,"type":"cone","u":[0],"v":[0],"w":[7.4],"x":[0],"y":[0],"z":[7.4]}],                        {"height":480,"legend":{"or ...

# %% [markdown]
# #**Vectores paralelos**
#
# Dados los vectores ${\displaystyle \vec{U},\vec{V}\in V_3}$ diferentes de cero:
#
# <center> Si $\ \vec{U}\times\vec{V}=\vec{0}$ entonces $\ \vec{U}$ y $\vec{V}$ son paralelos</center>
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/vectorespara.PNG?raw=true"  height="250"/> </center>
#
# ##**Ejemplo:**
# Dados el vector $\vec{A}= (1,-2,3)$  y $\vec{B}= (-2,4,-6)$ determina si los vectores son paralelos usando el producto vectorial, realiza la gráfica de los vectores en el mismo espacio.

# %%
A = Matrix([1,-2,3])
B = Matrix([-2,4,-6])

A.cross(B)
# Out:
# Matrix([
# [0],
# [0],
# [0]])

# %%
plotvectors3D(A,B)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="83bb990d-28e5-423b-bffd-0c98a7de5b3b" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("83bb990d-28e5-423b-bffd-0c98a7de5b3b")) {                    Plotly.newPlot(                        "83bb990d-28e5-423b-bffd-0c98a7de5b3b",                        [{"line":{"color":"rgb(82,59,80)","width":7},"marker":{"color":"rgb(82,59,80)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1.0],"y":[0,-2.0],"z":[0,3.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(82,59,80)"],[1,"rgb(82,59,80)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.26666666666666666,"type":"cone","u":[1.0],"v":[-2.0],"w":[3.0],"x":[1.0],"y":[-2.0],"z":[3.0]},{"line":{"color":"rgb(23,198,118)","width":7},"marker":{"color":"rgb(23,198,118)","size":1},"name":"vector 2","type":"scatter3d","x":[0,-2.0],"y":[0,4.0],"z":[0,-6.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(23,198,118)"],[1,"rgb(23,198,118)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.26666666666666666,"type":"cone","u":[-2.0],"v":[4.0],"w":[-6.0],"x":[-2.0],"y":[4.0],"z":[-6.0]},{"marker":{"color":"#2a3f5f","size":5},"mode":"markers","name":"origen","showlegend":true,"type":"scatter3d","x":[0],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[-2.2666666666666666,1.2666666666666666],"y":[0,0],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje x-positivo","showscale":false,"sizemode":"absolute","sizeref":0.16,"type":"cone","u":[1.2666666666666666],"v":[0],"w":[0],"x":[1.2666666666666666],"y":[0],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"","showlegend":false,"type":"scatter3d","x":[0,0],"y":[-2.2666666666666666,4.266666666666667],"z":[0,0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje y-positivo ","showscale":false,"sizemode":"absolute","sizeref":0.16,"type":"cone","u":[0],"v":[4.266666666666667],"w":[0],"x":[0],"y":[4.266666666666667],"z":[0]},{"hoverinfo":"skip","line":{"color":"#2a3f5f","width":3},"marker":{"color":"#2a3f5f","size":1},"name":"eje z-positivo","showlegend":false,"type":"scatter3d","x":[0,0],"y":[0,0],"z":[-6.266666666666667,3.2666666666666666]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"#2a3f5f"],[1,"#2a3f5f"]],"hoverinfo":"name","name":"Eje z-positivo","showscale":false,"sizemode":"absolute","sizeref":0.16,"type":"cone","u":[0],"v":[0],"w":[3.2666666666666666],"x":[0],"y":[0],"z":[3.2666666666666666]}],                        {"height":480,"legend":{"orientation":"h","x":0.03,"y":1.3},"margin":{"b":0,"l":0,"r":0,"t":0},"showlegend":true,"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscal ...

# %% [markdown]
# #**Volumen del paralelepipedo**
#
# Dados los vectores ${\displaystyle \vec{U},\vec{V},\vec{W} \in V_3}$ el **producto triple** estos estos tres vectores corresponde el volumen del paralelepipedo determinado por los tres vectores:
#
# $$  Volumen= |\vec{W} \cdot (\vec{U}\times\vec{V})| $$
# <br>
#
# <center><img src="https://github.com/josorio398/ALGEBRA-LINEAL-CON-PYTHON/blob/master/im%C3%A1genes%20repositorio/paralelepipedo.PNG?raw=true"  height="250" /> </center>
#
# ##**Ejemplo:**
# Dados el vector $\vec{A}= (1,2,3)$ , $\vec{B}= (4,5,6)$ y  $\vec{C}= (3,-1,4)$ realiza su gráfica de los tres vectores en el mismo  espacio y cálcula el volumen del paralelepipedo determinado por estos tres vectores.

# %%
A = Matrix([1,2,-4])
B = Matrix([2,3,4])
C = Matrix([3,-1,4])

plotvectors3D(A,B,C,[(3,-1,4),B],[(2,3,4),C],[(5,2,8),A],[(3,-1,4),A],[(2,3,4),A])
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.2.0.min.js"></script>                <div id="0ff08db1-2e31-4819-98e9-53dfb3a31561" class="plotly-graph-div" style="height:480px; width:480px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ff08db1-2e31-4819-98e9-53dfb3a31561")) {                    Plotly.newPlot(                        "0ff08db1-2e31-4819-98e9-53dfb3a31561",                        [{"line":{"color":"rgb(49,208,81)","width":7},"marker":{"color":"rgb(49,208,81)","size":1},"name":"vector 1","type":"scatter3d","x":[0,1.0],"y":[0,2.0],"z":[0,-4.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(49,208,81)"],[1,"rgb(49,208,81)"]],"name":"vector 1","showscale":false,"sizemode":"absolute","sizeref":0.6333333333333333,"type":"cone","u":[1.0],"v":[2.0],"w":[-4.0],"x":[1.0],"y":[2.0],"z":[-4.0]},{"line":{"color":"rgb(102,150,238)","width":7},"marker":{"color":"rgb(102,150,238)","size":1},"name":"vector 2","type":"scatter3d","x":[0,2.0],"y":[0,3.0],"z":[0,4.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(102,150,238)"],[1,"rgb(102,150,238)"]],"name":"vector 2","showscale":false,"sizemode":"absolute","sizeref":0.6333333333333333,"type":"cone","u":[2.0],"v":[3.0],"w":[4.0],"x":[2.0],"y":[3.0],"z":[4.0]},{"line":{"color":"rgb(84,121,200)","width":7},"marker":{"color":"rgb(84,121,200)","size":1},"name":"vector 3","type":"scatter3d","x":[0,3.0],"y":[0,-1.0],"z":[0,4.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(84,121,200)"],[1,"rgb(84,121,200)"]],"name":"vector 3","showscale":false,"sizemode":"absolute","sizeref":0.6333333333333333,"type":"cone","u":[3.0],"v":[-1.0],"w":[4.0],"x":[3.0],"y":[-1.0],"z":[4.0]},{"hoverinfo":"name+text","hovertext":"Tail=(3,-1,4)\nHead=(5.0,2.0,8.0)","line":{"color":"rgb(200,18,144)","width":7},"marker":{"color":"rgb(200,18,144)","size":1},"name":"vector 4","type":"scatter3d","x":[3,5.0],"y":[-1,2.0],"z":[4,8.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(200,18,144)"],[1,"rgb(200,18,144)"]],"hoverinfo":"skip","name":"vector 4","showscale":false,"sizemode":"absolute","sizeref":0.6333333333333333,"type":"cone","u":[1.0],"v":[1.5],"w":[2.0],"x":[4.874],"y":[1.811],"z":[7.748]},{"hoverinfo":"name+text","hovertext":"Tail=(2,3,4)\nHead=(5.0,2.0,8.0)","line":{"color":"rgb(15,29,224)","width":7},"marker":{"color":"rgb(15,29,224)","size":1},"name":"vector 5","type":"scatter3d","x":[2,5.0],"y":[3,2.0],"z":[4,8.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(15,29,224)"],[1,"rgb(15,29,224)"]],"hoverinfo":"skip","name":"vector 5","showscale":false,"sizemode":"absolute","sizeref":0.6333333333333333,"type":"cone","u":[1.5],"v":[-0.5],"w":[2.0],"x":[4.811],"y":[2.063],"z":[7.748]},{"hoverinfo":"name+text","hovertext":"Tail=(5,2,8)\nHead=(6.0,4.0,4.0)","line":{"color":"rgb(162,103,130)","width":7},"marker":{"color":"rgb(162,103,130)","size":1},"name":"vector 6","type":"scatter3d","x":[5,6.0],"y":[2,4.0],"z":[8,4.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(162,103,130)"],[1,"rgb(162,103,130)"]],"hoverinfo":"skip","name":"vector 6","showscale":false,"sizemode":"absolute","sizeref":0.6333333333333333,"type":"cone","u":[0.5],"v":[1.0],"w":[-2.0],"x":[5.937],"y":[3.874],"z":[4.252]},{"hoverinfo":"name+text","hovertext":"Tail=(3,-1,4)\nHead=(4.0,1.0,0.0)","line":{"color":"rgb(189,30,62)","width":7},"marker":{"color":"rgb(189,30,62)","size":1},"name":"vector 7","type":"scatter3d","x":[3,4.0],"y":[-1,1.0],"z":[4,0.0]},{"anchor":"cm","colorbar":{"thickness":20,"ticklen":4},"colorscale":[[0,"rgb(189,30,62)"],[1,"rgb(189,30,62)"]],"hoverinfo":"skip","name":"vector 7","showscale":false,"sizemode":"absolute","sizeref":0.6333333333333333,"type":"cone","u":[0.5],"v":[1.0],"w":[-2.0],"x ...

# %%
(A.cross(B)).dot(C)
# Out:
# 68
